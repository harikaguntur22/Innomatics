# %%
# ================================
# 1. User Login Check
# ================================

print("---- User Login Check ----")
username = "admin"
password = "1234"

input_username = input("Enter username: ")
input_password = input("Enter password: ")

if input_username == username and input_password == password:
    print("Login Successful")
else:
    print("Invalid Credentials")

print("\n")


# ================================
# 2. Pass / Fail Analyzer
# ================================

print("---- Pass / Fail Analyzer ----")
marks = [45, 78, 90, 33, 60]

pass_count = 0
fail_count = 0

for mark in marks:
    if mark >= 50:
        pass_count += 1
    else:
        fail_count += 1

print("Total Pass Students:", pass_count)
print("Total Fail Students:", fail_count)

print("\n")


# ================================
# 3. Simple Data Cleaner
# ================================

print("---- Simple Data Cleaner ----")
names = [" Alice ", "bob", " CHARLIE "]

cleaned_names = []

for name in names:
    cleaned_names.append(name.strip().lower())

print("Cleaned Names:", cleaned_names)

print("\n")


# ================================
# 4. Message Length Analyzer
# ================================

print("---- Message Length Analyzer ----")
messages = ["Hi", "Welcome to the platform", "OK"]

for msg in messages:
    print(f"Message: '{msg}' | Length: {len(msg)}")
    if len(msg) > 10:
        print("⚠️ Message longer than 10 characters")

print("\n")


# ================================
# 5. Error Message Detector
# ================================

print("---- Error Message Detector ----")
logs = ["INFO", "ERROR", "WARNING", "ERROR"]

error_count = 0

for log in logs:
    if log == "ERROR":
        error_count += 1

print("Total ERROR entries:", error_count)
# Out:
# ---- User Login Check ----
# Enter username: harikaguntur
# Enter password: Hari123
# Invalid Credentials
#
#
# ---- Pass / Fail Analyzer ----
# Total Pass Students: 3
# Total Fail Students: 2
#
#
# ---- Simple Data Cleaner ----
# Cleaned Names: ['alice', 'bob', 'charlie']
#
#
# ---- Message Length Analyzer ----
# Message: 'Hi' | Length: 2
# Message: 'Welcome to the platform' | Length: 23
# ⚠️ Message longer than 10 characters
# Message: 'OK' | Length: 2
#
#
# ---- Error Message Detector ----
# Total ERROR entries: 2
